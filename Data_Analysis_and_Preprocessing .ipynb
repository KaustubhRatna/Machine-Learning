# %%
import pandas

# %%
Raw_Housing_Data= pandas.read_csv("1. Regression - Module - (Housing Prices).csv")

# %%
Raw_Housing_Data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                None  ...             7
# ...

# %%
import numpy

# %%
Raw_Housing_Data.shape
# Out:
# (21613, 21)

# %%
21*21613
# Out:
# 453873

# %%
Raw_Housing_Data
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
for i in range(2):
    print(i*i)
# Out:
# 0
# 1

# %%
l1 =list()
l1.append([2,[5,6],4])
l1.extend([4,1,3])
print(l1[0][1][1]+l1[2])
# Out:
# 7

# %%
import matplotlib.pyplot as plt

# %%
data=Raw_Housing_Data

# %%
plt.scatter(x=data['ID'],y=data['Sale Price'])

# %%
data['Sale Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.401984e+05
# std      3.673890e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: Sale Price, dtype: float64

# %%
iqr=6.450000e+05-3.219500e+05

# %%
iqr
# Out:
# 323050.0

# %%
lower_limit=3.219500e+05-(1.5*iqr)

# %%
lower_limit
# Out:
# -162625.0

# %%
lower_limit=min(data['Sale Price'])

# %%
lower_limit
# Out:
# 75000.0

# %%
upper_limit=6.450000e+05+1.5*iqr

# %%
upper_limit
# Out:
# 1129575.0

# %%
import seaborn as sns

# %%
sns.boxplot(x=data['Sale Price'])
# Out:
# <AxesSubplot:xlabel='Sale Price'>

# %%
q1=data['Sale Price'].quantile(0.25)
q3=data['Sale Price'].quantile(0.75)

# %%
if((q3-q1)==iqr):
    print("noice")
else:
    print("noine")
# Out:
# noice

# %%
#solving outlier problem by replacing ouliers with limits

# %%
def limit_imputer(value):
    if value>upper_limit:
        return upper_limit
    if value<lower_limit:
        return lower_limit
    else:
        return value

# %%
data['Sale Price']=data['Sale Price'].apply(limit_imputer)

# %%
sns.boxplot(x=data['Sale Price'])
# Out:
# <AxesSubplot:xlabel='Sale Price'>

# %%
sns.boxplot(x=Raw_Housing_Data['Sale Price'])
# Out:
# <AxesSubplot:xlabel='Sale Price'>

# %%
plt.scatter(x=data['ID'],y=data['Sale Price'])

# %%
#Deleting missing values from our target variable i.e. sale price here
data.dropna(inplace=True,axis=0,subset=['Sale Price'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21605 non-null  float64
#  5   Flat Area (in Sqft)                        21600 non-null  float64
#  6   Lot Area (in Sqft)                         21600 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
Raw_Housing_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21605 non-null  float64
#  5   Flat Area (in Sqft)                        21600 non-null  float64
#  6   Lot Area (in Sqft)                         21600 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
plt.hist(data['Sale Price'],bins=10,color='green')
plt.xlabel("Intervals")
plt.ylabel("Selling Price")
plt.title("Histogram of Selling Price")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.isnull().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              4
# Flat Area (in Sqft)                          9
# Lot Area (in Sqft)                           9
# No of Floors                                 0
# Waterfront View                              0
# No of Times Visited                          0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      1
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# ...

# %%
Raw_Housing_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21605 non-null  float64
#  5   Flat Area (in Sqft)                        21600 non-null  float64
#  6   Lot Area (in Sqft)                         21600 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
numerical_columns=['No of Bathrooms','Flat Area (in Sqft)','Lot Area (in Sqft)','Area of the House from Basement (in Sqft)','Latitude','Longitude','Living Area after Renovation (in Sqft)']

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan,strategy='median')
data[numerical_columns]=imputer.fit_transform(data[numerical_columns])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Waterfront View                              0
# No of Times Visited                          0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      1
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       0
# ...

# %%
imputer = SimpleImputer(missing_values = np.nan, strategy="most_frequent")
data['Zipcode']=imputer.fit_transform(data['Zipcode'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-4c09cd5c7ccf> in <module>
#       1 imputer = SimpleImputer(missing_values = np.nan, strategy="most_frequent")
# ----> 2 data['Zipcode']=imputer.fit_transform(data['Zipcode'])
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\impute\_base.py in fit(self, X, y)
#     275         self : SimpleImputer
#     276         """
# --> 277         X = self._validate_input(X, in_fit=True)
#     278         super()._fit_indicator(X)
#     279
#
# ...

# %%
data['Zipcode'].shape    #zipcode is 1d array
# Out:
# (21609,)

# %%
#fit transform need a 2d array therefore we will reshape our zipcode
column=data['Zipcode'].values.reshape(-1,1)
column.shape  #now its a 2d array of 21609 X 1 size
# Out:
# (21609, 1)

# %%
imputer = SimpleImputer(missing_values = np.nan, strategy="most_frequent")
data['Zipcode']=imputer.fit_transform(column)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#converting the zipcode datatype to categorical dtype

# %%
data['Zipcode']=data['Zipcode'].astype(object)

# %%
data.dtypes
# Out:
# ID                                             int64
# Date House was Sold                           object
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Waterfront View                               object
# No of Times Visited                           object
# Condition of the House                        object
# Overall Grade                                  int64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                        int64
# Age of House (in Years)                        int64
# Renovated Year                                 int64
# Zipcode                                       object
# Latitude                                     float64
# ...

# %%
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                None  ...             7
# ...

# %%
data['No of Times Visited'].unique()  #it is an object type data but we will convert it into numeric to use it for model building
# Out:
# array(['None', 'Thrice', 'Four', 'Twice', 'Once'], dtype=object)

# %%
mapping ={0:'0',1:'1',2:'2',3:'3',4:'4'}
data['No of Times Visited']=data['No of Times Visited'].map(mapping)

# %%
data['No of Times Visited'].unique()
# Out:
# array([nan], dtype=object)

# %%
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                 NaN  ...             7
# ...

# %%
og_data= pandas.read_csv("1. Regression - Module - (Housing Prices).csv")

# %%
og_data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                None  ...             7
# ...

# %%
mapping ={'None':'0','Once':'1','Twice':'2','Thrice':'3','Four':'4'}
data['No of Times Visited']=og_data['No of Times Visited'].map(mapping)

# %%
data['No of Times Visited'].unique()
# Out:
# array(['0', '3', '4', '2', '1'], dtype=object)

# %%
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                   0  ...             7
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
og_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        21613 non-null  object
# ...

# %%
print('hello')
# Out:
# hello

# %%
data['Ever Renovate']=np.where(data['Renovated Year']==0,'No','Yes')

# %%
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ...  \
# 0              No                   0  ...
# 1              No                   0  ...
# ...

# %%
import pandas as pd
data['Purchase Year']=pd.DatetimeIndex(data['Date House was Sold']).year

# %%
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Basement Area (in Sqft)  \
# 0              No                   0  ...                       0
# ...

# %%
data['Years Since Renovation']=np.where(data['Ever Renovate']=='Yes',abs(data['Purchase Year']-data['Renovated Year']),0)

# %%
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Age of House (in Years)  \
# 0              No                   0  ...                      63
# ...

# %%
data.drop(columns=['Date House was Sold','Renovated Year','Purchase Year'],inplace=True)

# %%
data.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#   No of Times Visited Condition of the House  ...  \
# 0                   0                   Fair  ...
# 1                   0                   Fair  ...
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data['Sale Price'].corr(data['Flat Area (in Sqft)'])
# Out:
# 0.6951704258420669

# %%
np.corrcoef(data['Sale Price'],data['Flat Area (in Sqft)'])
# Out:
# array([[1.        , 0.69517043],
#        [0.69517043, 1.        ]])

# %%
data.corr()
# Out:
#                                                  ID  Sale Price  \
# ID                                         1.000000   -0.011529
# Sale Price                                -0.011529    1.000000
# No of Bedrooms                             0.001450    0.339407
# No of Bathrooms                            0.005233    0.535124
# Flat Area (in Sqft)                       -0.012379    0.695170
# Lot Area (in Sqft)                        -0.132153    0.101319
# No of Floors                               0.018653    0.298913
# Overall Grade                              0.013762    0.680914
# Area of the House from Basement (in Sqft) -0.010724    0.606527
# Basement Area (in Sqft)                   -0.005189    0.307513
# Age of House (in Years)                   -0.021524   -0.064306
# Latitude                                  -0.001983    0.402430
# Longitude                                  0.020720    0.045401
# Living Area after Renovation (in Sqft)    -0.002913    0.629944
# ...

# %%
data.drop(columns='ID').corr()  #correlation of all variables except id cause its of no use
# Out:
#                                            Sale Price  No of Bedrooms  \
# Sale Price                                   1.000000        0.339407
# No of Bedrooms                               0.339407        1.000000
# No of Bathrooms                              0.535124        0.515813
# Flat Area (in Sqft)                          0.695170        0.576628
# Lot Area (in Sqft)                           0.101319        0.031692
# No of Floors                                 0.298913        0.175536
# Overall Grade                                0.680914        0.349223
# Area of the House from Basement (in Sqft)    0.606527        0.477549
# Basement Area (in Sqft)                      0.307513        0.303294
# Age of House (in Years)                     -0.064306       -0.154113
# Latitude                                     0.402430       -0.008708
# Longitude                                    0.045401        0.129569
# ...

# %%
data.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#   No of Times Visited Condition of the House  ...  \
# 0                   0                   Fair  ...
# 1                   0                   Fair  ...
# ...

# %%
data.drop(columns = 'ID',inplace=True)

# %%
data.head()
# Out:
#    Sale Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors Waterfront View No of Times Visited  \
# 0              5650.0           1.0              No                   0
# 1              7242.0           2.0              No                   0
# 2             10000.0           1.0              No                   0
# 3              5000.0           1.0              No                   0
# 4              8080.0           1.0              No                   0
#
#   Condition of the House  Overall Grade  \
# 0                   Fair              7
# ...

# %%
data['Condition of the House'].head(10)
# Out:
# 0         Fair
# 1         Fair
# 2         Fair
# 3    Excellent
# 4         Fair
# 5         Fair
# 6         Fair
# 7         Fair
# 8         Fair
# 9         Fair
# Name: Condition of the House, dtype: object

# %%
data['Condition of the House'].value_counts()
# Out:
# Fair         14028
# Good          5678
# Excellent     1701
# Okay           172
# Bad             30
# Name: Condition of the House, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data.groupby('Condition of the House',)['Sale Price'].mean().sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Condition of the House'>

# %%
data.groupby('Waterfront View',)['Sale Price'].mean().sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Waterfront View'>

# %%
data.groupby('Ever Renovate',)['Sale Price'].mean().sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Ever Renovate'>

# %%
data.groupby('Zipcode',)['Sale Price'].mean().sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Zipcode'>

# %%
data['Zipcode'].dtypes
# Out:
# dtype('O')

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

# %%
data = data.rename(columns = { 'Sale Price' : 'Sale_Price' })

# %%
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors Waterfront View No of Times Visited  \
# 0              5650.0           1.0              No                   0
# 1              7242.0           2.0              No                   0
# 2             10000.0           1.0              No                   0
# 3              5000.0           1.0              No                   0
# 4              8080.0           1.0              No                   0
#
#   Condition of the House  Overall Grade  \
# 0                   Fair              7
# ...

# %%
data = data.rename(columns = { 'SCondition_of_the_House' : 'Condition_of_the_House' })
data = data.rename(columns = { 'Ever Renovate' : 'Ever_Renovate' })
data = data.rename(columns = { 'Waterfront View' : 'Waterfront_View' })
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors Waterfront_View No of Times Visited  \
# 0              5650.0           1.0              No                   0
# 1              7242.0           2.0              No                   0
# 2             10000.0           1.0              No                   0
# 3              5000.0           1.0              No                   0
# 4              8080.0           1.0              No                   0
#
#   Condition of the House  Overall Grade  \
# 0                   Fair              7
# ...

# %%
data = data.rename(columns = { 'Condition of the House' : 'Condition_of_the_House' })
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors Waterfront_View No of Times Visited  \
# 0              5650.0           1.0              No                   0
# 1              7242.0           2.0              No                   0
# 2             10000.0           1.0              No                   0
# 3              5000.0           1.0              No                   0
# 4              8080.0           1.0              No                   0
#
#   Condition_of_the_House  Overall Grade  \
# 0                   Fair              7
# ...

# %%
data['Waterfront_View'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
mod = ols('Sale_Price ~ Condition_of_the_House',data=data).fit()

# %%
Anova_Table = sm.stats.anova_lm(mod, typ = 2)

# %%
print(Anova_Table)
# Out:
#                               sum_sq       df         F        PR(>F)
# Condition_of_the_House  1.441831e+13      4.0  58.25563  5.447605e-49
# Residual                1.336752e+15  21604.0       NaN           NaN

# %%
mod = ols('Sale_Price ~ Waterfront_View',data=data).fit()
Anova_Table = sm.stats.anova_lm(mod, typ = 2)
print(Anova_Table)
# Out:
#                        sum_sq       df           F         PR(>F)
# Waterfront_View  3.283737e+13      1.0  538.192683  1.275558e-117
# Residual         1.318333e+15  21607.0         NaN            NaN

# %%
mod = ols('Sale_Price ~ Ever_Renovate',data=data).fit()
Anova_Table = sm.stats.anova_lm(mod, typ = 2)
print(Anova_Table)
# Out:
#                      sum_sq       df           F        PR(>F)
# Ever_Renovate  1.998463e+13      1.0  324.378469  5.419055e-72
# Residual       1.331185e+15  21607.0         NaN           NaN

# %%
mod = ols('Sale_Price ~ Zipcode',data=data).fit()
Anova_Table = sm.stats.anova_lm(mod, typ = 2)
print(Anova_Table)
# Out:
#                 sum_sq       df           F  PR(>F)
# Zipcode   6.859657e+14     69.0  321.902033     0.0
# Residual  6.652044e+14  21539.0         NaN     NaN

# %%
data=pd.get_dummies(data,columns=['Condition_of_the_House'],drop_first = True)

# %%
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors Waterfront_View No of Times Visited  \
# 0              5650.0           1.0              No                   0
# 1              7242.0           2.0              No                   0
# 2             10000.0           1.0              No                   0
# 3              5000.0           1.0              No                   0
# 4              8080.0           1.0              No                   0
#
#    Overall Grade  Area of the House from Basement (in Sqft)  ...  Latitude  \
# ...

# %%
data=pd.get_dummies(data,columns=['Waterfront_View','Ever_Renovate'],drop_first = True)

# %%
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                   0              7
# 1              7242.0           2.0                   0              7
# 2             10000.0           1.0                   0              6
# 3              5000.0           1.0                   0              7
# 4              8080.0           1.0                   0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %%
data['Waterfront_View_Yes'].unique()
# Out:
# array([0, 1], dtype=uint8)

# %%
data['Zipcode'].value_counts()
# Out:
# 98103.0    602
# 98038.0    590
# 98115.0    583
# 98052.0    574
# 98117.0    553
#           ...
# 98102.0    105
# 98010.0    100
# 98024.0     81
# 98148.0     57
# 98039.0     50
# Name: Zipcode, Length: 70, dtype: int64

# %%
data['Zipcode'].dtypes
# Out:
# dtype('O')

# %%
Zip_table = data.groupby('Zipcode').agg({'Sale_Price' : 'mean'}).sort_values('Sale_Price',ascending = True)

# %%
Zip_table.head()
# Out:
#             Sale_Price
# Zipcode
# 98002.0  234284.035176
# 98168.0  240328.371747
# 98032.0  251296.240000
# 98001.0  280804.690608
# 98148.0  284908.596491

# %%
Zip_table['Zipcode_Group']=pd.cut(Zip_table['Sale_Price'],bins=10,
                                 labels = ['Zipcode_Group_0',
                                          'Zipcode_Group_1',
                                          'Zipcode_Group_2',
                                          'Zipcode_Group_3',
                                          'Zipcode_Group_4',
                                          'Zipcode_Group_5',
                                          'Zipcode_Group_6',
                                          'Zipcode_Group_7',
                                          'Zipcode_Group_8',
                                          'Zipcode_Group_9'],
                                 include_lowest=True)
Zip_table=Zip_table.drop(columns = 'Sale_Price')

# %%
Zip_table.describe()
Zip_table
# Out:
#            Zipcode_Group
# Zipcode
# 98002.0  Zipcode_Group_0
# 98168.0  Zipcode_Group_0
# 98032.0  Zipcode_Group_0
# 98001.0  Zipcode_Group_0
# 98148.0  Zipcode_Group_0
# ...                  ...
# 98109.0  Zipcode_Group_6
# 98112.0  Zipcode_Group_7
# 98040.0  Zipcode_Group_8
# 98004.0  Zipcode_Group_8
# 98039.0  Zipcode_Group_9
#
# [70 rows x 1 columns]

# %%
Zip_table['Zipcode_Group'].value_counts()
# Out:
# Zipcode_Group_0    16
# Zipcode_Group_2    14
# Zipcode_Group_4    11
# Zipcode_Group_3     9
# Zipcode_Group_6     7
# Zipcode_Group_1     6
# Zipcode_Group_5     3
# Zipcode_Group_8     2
# Zipcode_Group_9     1
# Zipcode_Group_7     1
# Name: Zipcode_Group, dtype: int64

# %%
data=pd.merge(data,Zip_table,left_on='Zipcode',how = 'left',right_index=True)

# %%
data=data.drop(columns = 'Zipcode')

# %%
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                   0              7
# 1              7242.0           2.0                   0              7
# 2             10000.0           1.0                   0              6
# 3              5000.0           1.0                   0              7
# 4              8080.0           1.0                   0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %%
data=pd.get_dummies(data,columns=['Zipcode_Group'],drop_first = True)

# %%
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                   0              7
# 1              7242.0           2.0                   0              7
# 2             10000.0           1.0                   0              6
# 3              5000.0           1.0                   0              7
# 4              8080.0           1.0                   0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %%
Y = data.iloc[:,0]

# %%
print(Y)
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: Sale_Price, Length: 21609, dtype: float64

# %%
Y.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: Sale_Price, dtype: float64

# %%
Y.head
# Out:
# <bound method NDFrame.head of 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: Sale_Price, Length: 21609, dtype: float64>

# %%
X= data.iloc[:,1:31]

# %%
X.head()
# Out:
#    No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  \
# 0               3             1.00               1180.0              5650.0
# 1               3             2.25               2570.0              7242.0
# 2               2             1.00                770.0             10000.0
# 3               4             3.00               1960.0              5000.0
# 4               3             2.00               1680.0              8080.0
#
#    No of Floors No of Times Visited  Overall Grade  \
# 0           1.0                   0              7
# 1           2.0                   0              7
# 2           1.0                   0              6
# 3           1.0                   0              7
# 4           1.0                   0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                     1180.0                        0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
X_train.shape
# Out:
# (15126, 30)

# %%
Y_train.shape
# Out:
# (15126,)

# %%
Y_train.head()
# Out:
# 20049    580000.0
# 12465    222900.0
# 1245     410500.0
# 17413    630100.0
# 5288     279000.0
# Name: Sale_Price, dtype: float64

# %%
X_test.shape
# Out:
# (6483, 30)

# %%
Y_train.head()
# Out:
# 20049    580000.0
# 12465    222900.0
# 1245     410500.0
# 17413    630100.0
# 5288     279000.0
# Name: Sale_Price, dtype: float64

# %%
Y_train.describe()
# Out:
# count    1.512600e+04
# mean     5.116403e+05
# std      2.506782e+05
# min      7.500000e+04
# 25%      3.200000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      1.129575e+06
# Name: Sale_Price, dtype: float64

# %%
X_train.describe()
# Out:
#        No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# count    15126.000000     15126.000000         15126.000000
# mean         3.368306         2.115182          2078.295385
# std          0.899923         0.774320           925.955870
# min          0.000000         0.000000           370.000000
# 25%          3.000000         1.500000          1420.000000
# 50%          3.000000         2.250000          1910.000000
# 75%          4.000000         2.500000          2540.000000
# max         11.000000         8.000000         13540.000000
#
#        Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count        1.512600e+04  15126.000000   15126.000000
# mean         1.513542e+04      1.494414       7.621843
# std          3.971610e+04      0.539070       1.110817
# min          5.200000e+02      1.000000       2.000000
# 25%          5.040000e+03      1.000000       7.000000
# 50%          7.601000e+03      1.500000       7.000000
# ...

# %% [markdown]
# # Standardisation

# %%
from sklearn import preprocessing 
scale = preprocessing.StandardScaler()
X_train = scale.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.70196488,  1.46561566,  1.60996214, ..., -0.11278716,
#         -0.17064468, -0.05149238],
#        [-1.52051984, -1.44025699, -1.04575977, ..., -0.11278716,
#         -0.17064468, -0.05149238],
#        [ 0.70196488,  0.49699144, -0.10615909, ..., -0.11278716,
#         -0.17064468, -0.05149238],
#        ...,
#        [ 1.81320724,  0.1741167 , -0.35455927, ..., -0.11278716,
#         -0.17064468, -0.05149238],
#        [-0.40927748,  0.1741167 , -0.60295945, ..., -0.11278716,
#         -0.17064468, -0.05149238],
#        [ 0.70196488,  0.49699144,  0.76864154, ..., -0.11278716,
#         -0.17064468, -0.05149238]])

# %%
X_test = scale.fit_transform(X_test)

# %%
X_test
# Out:
# array([[-0.37789826, -1.46497625, -1.10353341, ..., -0.11106773,
#         -0.16459421, -0.03930495],
#        [-0.37789826,  0.50831297,  0.31815588, ..., -0.11106773,
#         -0.16459421, -0.03930495],
#        [-0.37789826, -0.47833164, -0.84807361, ..., -0.11106773,
#         -0.16459421, -0.03930495],
#        ...,
#        [ 0.6257537 , -0.1494501 , -0.60372077, ..., -0.11106773,
#         -0.16459421, -0.03930495],
#        [ 2.63305761,  1.82383912,  0.04048219, ..., -0.11106773,
#         -0.16459421, -0.03930495],
#        [-0.37789826, -0.1494501 ,  0.4847601 , ..., -0.11106773,
#         -0.16459421, -0.03930495]])
